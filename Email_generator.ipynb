# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    temperature=0,
    groq_api_key="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",
    model="llama-3.3-70b-versatile"
)
response = llm.invoke("The First Person to land on the moon?")
print(response.content)
# Out:
# The first person to land on the moon was Neil Armstrong. He stepped out of the lunar module Eagle and onto the moon's surface on July 20, 1969, during the Apollo 11 mission. Armstrong famously declared, "That's one small step for man, one giant leap for mankind," as he became the first human to set foot on the moon.

# %%
from langchain_community.document_loaders import WebBaseLoader

loader = WebBaseLoader("https://careers.nike.com/software-engineer/job/R-72423")
page_data = loader.load().pop().page_content.
print(page_data)
# Out:
# Software Engineer
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Skip to main content
# Open Virtual Assistant
#
#
#
#
#
#
#
#
#
#
# Home
#
#
# Career Areas
#
#
# Total Rewards
#
#
# Life@Nike
#
#
# Purpose
#
#
#
#
#
#
#
#
#
#
# Language
#
#
#
#
#
# Select a Language
#
#   Deutsch
#   English
#   Español (España)
#   Español (América Latina)
#   Français
#   Italiano
#   Nederlands
#   Polski
#   Tiếng Việt
#   Türkçe
#   简体中文
#   繁體中文
#   עִברִית
#   한국어
#   日本語
#
#
#
#
#
#
#
#
# Careers
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Close Menu
#
#
#
#
#
#
#
# Careers
#
#
#
#
#
#
# Chat
#
#
#
#
#
#
#                                 Home
#
#
#
#
#                                 Career Areas
#
#
#
#
#                                 Total Rewards
#
#
#
#
#                                 Life@Nike
#
#
#
#
#                                 Purpose
#
#
#
#
#
#
#
#
#
#
#
# Jordan Careers
#
#
#
#
#
#
#
# Converse Careers
#
#
#
#
#
#
#
#
#
#
# Language
#
# ...

# %%
from langchain_core.prompts import PromptTemplate

prompt_extract = PromptTemplate.from_template(
    """
    ### Scraped text from a job posting:
    {page_data} 
    ### Instructions:
    The scaped text is from a job posting of website. 
    your task is to extract the following information from the text in JSON format containg following keys:
    'role', 'experience', 'skills', 'descrription'.
    only return valid JSON.
    ### valid json no preamble:
    """
    )

chain_extract = prompt_extract | llm
response = chain_extract.invoke(input={"page_data": page_data})
print(response.content)
# Out:
# str

# %%
from langchain_core.output_parsers import JsonOutputParser

json_parser = JsonOutputParser()
parsed_response = json_parser.parse(response.content)
print(parsed_response)
# Out:
# {'role': 'Software Engineer', 'experience': 'Various career stages—from early-career professionals eager to grow, to seasoned experts ready to lead and innovate', 'skills': ['Python', 'NodeJS', 'JavaScript (ES5/ES6)', 'Java', 'Linux environments', 'Containerization with Docker', 'Scripting languages such as Python or Bash', 'Kubernetes fundamentals', 'CI/CD pipelines', 'AWS automation infrastructure (EC2, Lambda, API Gateway, S3, CloudWatch)', 'AIOps', 'RPA platforms', 'AI/ML frameworks including LangChain, MLFlow, Databricks, and GPT-4o', 'Open-source automation tools for Web and Mobile platforms such as Playwright, Cypress, Espresso, and XCUITest'], 'description': 'Design, build, and operate scalable, secure, and high-performing technology solutions that support Nike’s global platforms'}
